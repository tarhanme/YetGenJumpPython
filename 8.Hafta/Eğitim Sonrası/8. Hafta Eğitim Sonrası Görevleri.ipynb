# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
import time
def vkiHesaplama(kilo,boy):
    vki= kilo/(boy**2)
    return round(vki,1)
def degerAraligi(vki):
    if vki< 18.5:
        return "ZAYIF"
    elif vki<=24.9:
        return "NORMAL KİLOLU"
    elif vki<= 29.9:
        return "FAZLA KİLOLU"
    elif vki<= 39.9:  
        return "OBEZ"
    else:
        return "İLERİ DERECEDE OBEZ"
    
def ciktilar(isim,yas,kilo,boy,vki,deger):
    kayitTarihi = time.ctime(time.time())
    t1 = f"kullanıcı adı {isim}\n"
    t2 = f"kullanıcının yaş, kilo, boy bilgisi {yas}, {kilo}, {boy}\n"
    t3 = f"kullanıcının vki {vki}\n"
    t4 = f"değer aralığı {deger}\n"
    t5 = f"oluşturma tarihi {kayitTarihi}\n"

    cıktı = t1+t2+t3+t4+t5
    return cıktı
def main():
    girisSayisi=int(input("kaç kullanıcı girişi yapılacak: "))
    for i in range(girisSayisi):
        isim = (input("isim ve soyisim: "))
        yas = int(input("yaş: "))
        kilo = float(input("kilo: "))
        boy = float(input("boy: "))
        vki = vkiHesaplama(kilo,boy)
        deger = degerAraligi(vki)
        cıktı = ciktilar(isim,yas,kilo,boy,vki,deger)
    
        with open("saglık.txt", "a", encoding="utf-8") as f:
            f.write(cıktı)
            f.write("*"*20)
            f.write("\n")
            print("kullanıcı kaydedildi.")

        print("veriler 'saglık.txt' dosyasına kaydedildi. \n")
main()
# Out:
# kullanıcı kaydedildi.
# veriler 'saglık.txt' dosyasına kaydedildi.
#
# kullanıcı kaydedildi.
# veriler 'saglık.txt' dosyasına kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

import time
menu = {
    "elma":0.50,
    "armut":0.75,
    "kiraz":2.,
    "cilek":1.75,
    "ananas":2.,
    "kavun":2.15,
    "karpuz":1.99,
}

def displayMenu():
    print("YETBAR MENU")
    for item in list(menu.keys()):
        print(f"{item.upper():<10} : {menu[item]} TL")
    
def tekUrunFiyatı(urun,adet):
    assert adet >= 0 , "ürün adeti 0 ve 0'dan küçük olmaz."
    if urun not in list(menu.keys()):
        return None
    else:
        return menu[urun] * adet
    
def satinAlma():
    displayMenu()
    print("Lütfen satın alacağınız ürünü giriniz. Çıkış için '0'a basınız")

    satinAlinanUrun = []
    satinAlmaAdeti = []

    sonFiyat = 0
    while 1:
        eklenecekUrun = input("Hangi üründen eklemek istiyorsunuz: ")
        if eklenecekUrun == "0":
            print("Fiş oluşturuluyor.")
            break
        eklemeAdedi = int(input("Kaç adet eklenecej: "))
        fiyat = tekUrunFiyatı(eklenecekUrun , eklemeAdedi)
        if fiyt is None:
            print("Yanlış bir giriş yaptınız, ürün eklenemedi.")
        else:
            print(f"Satın alma ücreti: {fiyat}.\nSarın almayı onaylamak için 'y' iptal etmek için 'n' giriniz")
            check = input("Satın almayı onaylıyor musunuz? ")
            if check == "y":
                print("Satın alma onaylandı.")
                print("-"*40)
                sonFiyat += fiyat
                satinAlinanUrun.append(eklenecekUrun)
                satinAlmaAdeti.append(eklemeAdedi)
                print(f"Ara Toplam: {sonFiyat}")
            elif check == "n":
                print("Satın alma işlemini iptal ey")
                print("-"*40)
        return sonFiyat, satinAlinanUrun , satinAlmaAdeti
    
    def main ():
        print("YetBar'a hoşgeldiniz!\nMenüyü görmek için '1'e, smoothie için '2'ye çıkmak için '0'a basınız")
        program = None
        while 1:
            program = int(input("Tercihiniz nedir: "))
            if program < 0 or program > 2:
                print("Yanlış tercih!)")
            elif program == 0:
                print("Çıkış yapılıor.")
                break
            elif program == 1:
                displayMenu()
            elif program == 2:
                satinAlmaUcreti,satinAlinanUrun,satinAlmaAdeti = satinAlma()
                with open("saglık.txt","a",encoding="utf-8") as f:
                    f.write(str(time.ctime(time.time())))
                    f.write("\n")
                    f.write(','.k-join(map(str,satinAlinanUrun)))
                    f.write("\n")
                    f.write(','.k-join(map(str,satinAlmaAdeti)))
                    f.write("\n")
                    f.write(f"Toplam: {satinAlmaUcreti}")
                    f.write("\n")
                    f.write("*"*20)
                    f.write("\n")
                cikis = input("Başka işlem yapacak mısınız: ")
                if cikis == "evet":
                    pass
                else:
                    print("İşlem bitti.")
                    break

main()
# Out:
# kullanıcı kaydedildi.
# veriler 'saglık.txt' dosyasına kaydedildi.
