# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
import random
import time


class kumanda():
    def __init__(self, tv_durum="kapalı", ses=0 , kanallar = ["kanal1" , "kanal2" , "kanal3"], kanal = "KanalD"):
        self.tv_durum = tv_durum
        self.ses = ses
        self.kanallar = kanallar

    def tv_ac(self):
        if (self.tv_durum == "TV Açık"):
            print("TV AÇIK....")
        else:
            print("TV Açılıyor...")
            self.tv_durum = "AÇIK"

    def tv_kapat(self):
        if self.tv_durum == "TV Kapalı":
            print("TV KAPALI...")
        else:
            if (self.otomat_durum == "kapalı"):
                print("Otomat zaten kapalı....")
            else:
                print("TV kapanıyor...")
                self.tv_durum = "kapalı"

    def ses(self):
        while True:
            sesAyari = input("Sesi Açın: '>'" , "Sesi Kısın: '<'")
            if (sesAyari == "<"):
                 if (self.ses != 0):
                      self.ses -= 1
                      print("Sesler: " , self.ses)
            elif (sesAyari == ">"):
                 if (self.ses != 20):
                      self.ses += 1
                      print("Sesler: " , self.ses)
            else:
                 print("Ses Ayarı Değiştirildi:" , self.ses)

    def kanalEkle(self,kanalAdi):
        print("Kanal ekleniyor.")
        time.sleep(1)
        self.kanallar.append(kanalAdi)
        print("Kanal Eklendi.")

    def randomKanal(self):
        random = random.randint(0,len(self.kanallar)-1)
        self.kanallar = self.kanallar[random]
        print("Açılan Kanal: " , self.kanal)

    def __len__(self):
        return len(self.kanallar)
    def __str__(self):
        return "TV Durumu: {} \nTV Sesi:{} \nAçılan Kanal: {} \n".format(self.tv_durum, self.ses, self.kanallar, self.kanal)      


kumanda = kumanda()

print("""
Televizyon Kumandası
1. Tv Aç
2. Tv Kapat
3. Ses Ayarları
4. Kanal Ekle
5. Kanal Sayısını Öğrenme
6. Rastgele Kanala Geçme
7. Televizyon Bilgileri
Çıkış için lütfen q tuşuna basınız""")


while True:
    islem = input("Yapmak istediğiniz işlemi seçiniz:")
    if (islem == "q"):
        print("Çıkış yapılıyor.")
        break
    elif (islem == "1"):
        kumanda.tv_ac()
    elif (islem == "2"):
        kumanda.tv_kapat()
    elif (islem == "3"):
        kumanda.ses()
    elif (islem == "4"):
        kanalAdi = input("Eklenecek kanal adlarını giriniz:")
        kanallar = kanalAdi.split(",")
        for i in kanallar:
            kumanda.kanalEkle(i)
    elif (islem == "5"):
        print("Kanal Sayısı:" , len(kumanda))
    elif (islem == "6"):
        kumanda.randomKanal()
    elif (islem == "7"):
        print(kumanda)
    else:
        print("Geçersiz İşlem Yapıldı")
# Out:
# Televizyon Kumandası
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
# Çıkış için lütfen q tuşuna basınız
# TV Açılıyor...
# Geçersiz İşlem Yapıldı
# Geçersiz İşlem Yapıldı
# Geçersiz İşlem Yapıldı
# TV Açılıyor...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 84
#      82     kumanda.tv_kapat()
#      83 elif (islem == "3"):
# ---> 84     kumanda.ses()
#      85 elif (islem == "4"):
#      86     kanalAdi = input("Eklenecek kanal adlarını giriniz:")
#
# TypeError: 'int' object is not callable
